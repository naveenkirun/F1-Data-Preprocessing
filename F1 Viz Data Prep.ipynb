# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
results=pd.read_csv('H:\\Aim\\MDE\\Database\\F1\\Dataset\\results.csv')
races=pd.read_csv('H:\\Aim\\MDE\\Database\\F1\\Dataset\\races.csv')
drivers=pd.read_csv('H:\\Aim\\MDE\\Database\\F1\\Dataset\\drivers.csv')
constructors=pd.read_csv('H:\\AIM\\MDE\\Database\\F1\\Dataset\\constructors.csv')

# %%
df=pd.merge(results,races[['raceId','year','name','round']],on='raceId',how='left')
df=pd.merge(df,drivers[['driverId','driverRef','code','forename','surname','nationality']],on='driverId',how='left')
df=pd.merge(df,constructors[['constructorId','constructorRef','name','nationality']],on='constructorId',how='left')

# %%
df.drop(['number','position','positionText','laps','fastestLap','statusId','resultId','raceId','driverId','constructorId'],axis=1,inplace=True)
df.rename(columns={'rank':'fastestLapRank','name_x':'gpName','nationality_x':'driverNationality','name_y':'constructorName','nationality_y':'constructorNationality','driverRef':'driver','code':'driverCode'},inplace=True)
df['driverName']=df['forename'] +" "+ df["surname"]
df
# Out:
#        grid  positionOrder  points         time milliseconds fastestLapRank  \
# 0         1              1    10.0  1:34:50.616      5690616              2
# 1         5              2     8.0       +5.478      5696094              3
# 2         7              3     6.0       +8.163      5698779              5
# 3        11              4     5.0      +17.181      5707797              7
# 4         3              5     4.0      +18.014      5708630              1
# ...     ...            ...     ...          ...          ...            ...
# 25835    12             16     0.0           \N           \N             12
# 25836    16             17     0.0           \N           \N             20
# 25837     5             18     0.0           \N           \N             11
# 25838    20             19     0.0           \N           \N             14
# 25839    10             20     0.0           \N           \N             17
#
# ...

# %%
df=df[['year','gpName','round','driverCode','driverName','driver','constructorName','grid','positionOrder','points','time','milliseconds','fastestLapRank','fastestLapTime','fastestLapSpeed','driverNationality','constructorNationality']]

# %%
 df=df[df['year']!=2019]
df=df.sort_values(by=['year','round','positionOrder'],ascending=[False,True,True])

# %%
df
# Out:
#        year              gpName  round driverCode       driverName  \
# 25400  2022  Bahrain Grand Prix      1        LEC  Charles Leclerc
# 25401  2022  Bahrain Grand Prix      1        SAI     Carlos Sainz
# 25402  2022  Bahrain Grand Prix      1        HAM   Lewis Hamilton
# 25403  2022  Bahrain Grand Prix      1        RUS   George Russell
# 25404  2022  Bahrain Grand Prix      1        MAG  Kevin Magnussen
# ...     ...                 ...    ...        ...              ...
# 20171  1950  Italian Grand Prix      7         \N  Consalvo Sanesi
# 20172  1950  Italian Grand Prix      7         \N    Robert Manzon
# 20173  1950  Italian Grand Prix      7         \N      Prince Bira
# 20174  1950  Italian Grand Prix      7         \N     Paul Pietsch
# 20175  1950  Italian Grand Prix      7         \N   Felice Bonetto
#
#                 driver constructorName  grid  positionOrder  points  \
# 25400          leclerc         Ferrari     1              1    26.0
# ...

# %%
df.time.replace('\\N',np.nan,inplace=True)
df.milliseconds.replace('\\N',np.nan,inplace=True)
df.fastestLapRank.replace('\\N',np.nan,inplace=True)
df.fastestLapTime.replace('\\N',np.nan,inplace=True)
df.fastestLapSpeed.replace('\\N',np.nan,inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#        year              gpName  round driverCode       driverName  \
# 0      2022  Bahrain Grand Prix      1        LEC  Charles Leclerc
# 1      2022  Bahrain Grand Prix      1        SAI     Carlos Sainz
# 2      2022  Bahrain Grand Prix      1        HAM   Lewis Hamilton
# 3      2022  Bahrain Grand Prix      1        RUS   George Russell
# 4      2022  Bahrain Grand Prix      1        MAG  Kevin Magnussen
# ...     ...                 ...    ...        ...              ...
# 25415  1950  Italian Grand Prix      7         \N  Consalvo Sanesi
# 25416  1950  Italian Grand Prix      7         \N    Robert Manzon
# 25417  1950  Italian Grand Prix      7         \N      Prince Bira
# 25418  1950  Italian Grand Prix      7         \N     Paul Pietsch
# 25419  1950  Italian Grand Prix      7         \N   Felice Bonetto
#
#                 driver constructorName  grid  positionOrder  points  \
# 0              leclerc         Ferrari     1              1    26.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25420 entries, 0 to 25419
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    25420 non-null  int64
#  1   gpName                  25420 non-null  object
#  2   round                   25420 non-null  int64
#  3   driverCode              25420 non-null  object
#  4   driverName              25420 non-null  object
#  5   driver                  25420 non-null  object
#  6   constructorName         25420 non-null  object
#  7   grid                    25420 non-null  int64
#  8   positionOrder           25420 non-null  int64
#  9   points                  25420 non-null  float64
#  10  time                    6892 non-null   object
#  11  milliseconds            6891 non-null   object
#  12  fastestLapRank          7171 non-null   object
#  13  fastestLapTime          6963 non-null   object
# ...

# %%
df.head(20)
# Out:
#     year              gpName  round driverCode        driverName  \
# 0   2022  Bahrain Grand Prix      1        LEC   Charles Leclerc
# 1   2022  Bahrain Grand Prix      1        SAI      Carlos Sainz
# 2   2022  Bahrain Grand Prix      1        HAM    Lewis Hamilton
# 3   2022  Bahrain Grand Prix      1        RUS    George Russell
# 4   2022  Bahrain Grand Prix      1        MAG   Kevin Magnussen
# 5   2022  Bahrain Grand Prix      1        BOT   Valtteri Bottas
# 6   2022  Bahrain Grand Prix      1        OCO      Esteban Ocon
# 7   2022  Bahrain Grand Prix      1        TSU      Yuki Tsunoda
# 8   2022  Bahrain Grand Prix      1        ALO   Fernando Alonso
# 9   2022  Bahrain Grand Prix      1        ZHO       Guanyu Zhou
# 10  2022  Bahrain Grand Prix      1        MSC   Mick Schumacher
# 11  2022  Bahrain Grand Prix      1        STR      Lance Stroll
# 12  2022  Bahrain Grand Prix      1        ALB   Alexander Albon
# ...

# %%
df.to_csv('H:\\Aim\\MDE\\Database\\F1\\Results\\RaceResults_1.csv')

# %%
df.head(20)
# Out:
#     year              gpName  round driverCode        driverName  \
# 0   2022  Bahrain Grand Prix      1        LEC   Charles Leclerc
# 1   2022  Bahrain Grand Prix      1        SAI      Carlos Sainz
# 2   2022  Bahrain Grand Prix      1        HAM    Lewis Hamilton
# 3   2022  Bahrain Grand Prix      1        RUS    George Russell
# 4   2022  Bahrain Grand Prix      1        MAG   Kevin Magnussen
# 5   2022  Bahrain Grand Prix      1        BOT   Valtteri Bottas
# 6   2022  Bahrain Grand Prix      1        OCO      Esteban Ocon
# 7   2022  Bahrain Grand Prix      1        TSU      Yuki Tsunoda
# 8   2022  Bahrain Grand Prix      1        ALO   Fernando Alonso
# 9   2022  Bahrain Grand Prix      1        ZHO       Guanyu Zhou
# 10  2022  Bahrain Grand Prix      1        MSC   Mick Schumacher
# 11  2022  Bahrain Grand Prix      1        STR      Lance Stroll
# 12  2022  Bahrain Grand Prix      1        ALB   Alexander Albon
# ...

# %%
drivers_2022=['de_vries','vettel','leclerc','sainz','hamilton','russell','kevin_magnussen','bottas','ocon','tsunoda','alonso','zhou','mick_schumacher','stroll','albon','ricciardo','norris','latifi','hulkenberg','perez','max_verstappen','gasly']
df=df[df['driver'].isin(drivers_2022)]
df
# Out:
#       year                    gpName  round driverCode       driverName  \
# 0     2022        Bahrain Grand Prix      1        LEC  Charles Leclerc
# 1     2022        Bahrain Grand Prix      1        SAI     Carlos Sainz
# 2     2022        Bahrain Grand Prix      1        HAM   Lewis Hamilton
# 3     2022        Bahrain Grand Prix      1        RUS   George Russell
# 4     2022        Bahrain Grand Prix      1        MAG  Kevin Magnussen
# ...    ...                       ...    ...        ...              ...
# 8274  2001      Hungarian Grand Prix     13        ALO  Fernando Alonso
# 8300  2001        Belgian Grand Prix     14        ALO  Fernando Alonso
# 8313  2001        Italian Grand Prix     15        ALO  Fernando Alonso
# 8343  2001  United States Grand Prix     16        ALO  Fernando Alonso
# 8355  2001       Japanese Grand Prix     17        ALO  Fernando Alonso
#
#                driver constructorName  grid  positionOrder  points  \
# ...

# %%
races2019=pd.read_csv('H:\\Aim\\MDE\\Database\\F1\\Dataset\\formula1_2019season_raceResults.csv')
driverdet=pd.read_csv('H:\\Aim\\MDE\\Database\\F1\\Results\\Useful\\DriverAgeDet_1.csv')

# %%
races2019_u=pd.merge(races2019,driverdet,on='driverName',how='left')

# %%
races_w2019=pd.concat([df,races2019_u])

# %%
races_w2019.drop(['team','currentRank','age'],axis=1,inplace=True)
races_w2019
# Out:
#      year                gpName  round driverCode          driverName  \
# 0    2022    Bahrain Grand Prix      1        LEC     Charles Leclerc
# 1    2022    Bahrain Grand Prix      1        SAI        Carlos Sainz
# 2    2022    Bahrain Grand Prix      1        HAM      Lewis Hamilton
# 3    2022    Bahrain Grand Prix      1        RUS      George Russell
# 4    2022    Bahrain Grand Prix      1        MAG     Kevin Magnussen
# ..    ...                   ...    ...        ...                 ...
# 415  2019  Abu Dhabi Grand Prix     21        NaN  Antonio Giovinazzi
# 416  2019  Abu Dhabi Grand Prix     21        RUS      George Russell
# 417  2019  Abu Dhabi Grand Prix     21        GAS        Pierre Gasly
# 418  2019  Abu Dhabi Grand Prix     21        NaN       Robert Kubica
# 419  2019  Abu Dhabi Grand Prix     21        STR        Lance Stroll
#
#               driver            constructorName  grid positionOrder  points  \
# ...

# %%
races_w2019=races_w2019.sort_values(by=['year','round','positionOrder'],ascending=[False,True,True])

# %%
races_w2019.time.replace('\\N',np.nan,inplace=True)
races_w2019.milliseconds.replace('\\N',np.nan,inplace=True)
races_w2019.fastestLapRank.replace('\\N',np.nan,inplace=True)
races_w2019.fastestLapTime.replace('\\N',np.nan,inplace=True)
races_w2019.fastestLapSpeed.replace('\\N',np.nan,inplace=True)
races_w2019.reset_index(drop=True,inplace=True)

# %%
races_w_01_22=races_w2019[races_w2019['driver'].isin(drivers_2022)]

# %%
races_w_01_22
# Out:
#       year                    gpName  round driverCode       driverName  \
# 0     2022        Bahrain Grand Prix      1        LEC  Charles Leclerc
# 1     2022        Bahrain Grand Prix      1        SAI     Carlos Sainz
# 2     2022        Bahrain Grand Prix      1        HAM   Lewis Hamilton
# 3     2022        Bahrain Grand Prix      1        RUS   George Russell
# 4     2022        Bahrain Grand Prix      1        MAG  Kevin Magnussen
# ...    ...                       ...    ...        ...              ...
# 3229  2001      Hungarian Grand Prix     13        ALO  Fernando Alonso
# 3230  2001        Belgian Grand Prix     14        ALO  Fernando Alonso
# 3231  2001        Italian Grand Prix     15        ALO  Fernando Alonso
# 3232  2001  United States Grand Prix     16        ALO  Fernando Alonso
# 3233  2001       Japanese Grand Prix     17        ALO  Fernando Alonso
#
#                driver constructorName  grid positionOrder  points  \
# ...

# %%
races_w_01_22.to_csv('H:\\Aim\\MDE\\Database\\F1\\Results\\Uptodate_results_03.csv')
